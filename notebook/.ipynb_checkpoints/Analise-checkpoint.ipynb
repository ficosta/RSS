# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import nltk
from datetime import datetime, timedelta
from wordcloud import WordCloud
from nltk.stem import RSLPStemmer
from pymongo import MongoClient

# %%
def Tokenize(sentence):
    sentence = sentence.lower()
    sentence = nltk.word_tokenize(sentence)
    return sentence

# %%
def RemoveStopWords(sentence):
    stopwords = nltk.corpus.stopwords.words('portuguese')
    phrase = []
    for word in sentence:
        if word not in stopwords:
            phrase.append(word)
    return phrase

# %%
def Stemming(sentence):
    stemmer = RSLPStemmer()
    phrase = []
    for word in sentence:
        phrase.append(stemmer.stem(word.lower()))
    return phrase

# %%
frase1 = df.title[0]
frase2 = df.title[2]
print(frase1)
print(frase2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-236-1068c32fd36e> in <module>
# ----> 1 frase1 = df.title[0]
#       2 frase2 = df.title[2]
#       3 print(frase1)
#       4 print(frase2)
#
# NameError: name 'df' is not defined

# %%
nltk.download('rslp')
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package rslp to /Users/Felipe/nltk_data...
# [nltk_data]   Package rslp is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/Felipe/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/Felipe/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def Train():
    training_data = []
    for row in df.iterrows():
        training_data.append({"classe":row[1][1], "frase":row[1][3]})
    print("%s frases incluidas" % len(training_data))
    return training_data

# %%
dados = Train()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-7b1e110c8841> in <module>
# ----> 1 dados = Train()
#
# <ipython-input-7-b0dacb027d2c> in Train()
#       1 def Train():
#       2     training_data = []
# ----> 3     for row in df.iterrows():
#       4         training_data.append({"classe":row[1][1], "frase":row[1][3]})
#       5     print("%s frases incluidas" % len(training_data))
#
# NameError: name 'df' is not defined

# %%
def Learning(training_data):
    corpus_words = {}
    for data in training_data:
        frase = data['frase']
        frase = Tokenize(frase)
        frase = Stemming(frase)
        frase = RemoveStopWords(frase)
        class_name = data['classe']
        if class_name not in list(corpus_words.keys()):
            corpus_words[class_name] = {}
        for word in frase:
            if word not in list(corpus_words[class_name].keys()):
                corpus_words[class_name][word] = 1
            else:
                corpus_words[class_name][word] += 1
    return corpus_words

# %%
dados = Learning(dados)
print(dados)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4c711032b263> in <module>
# ----> 1 dados = Learning(dados)
#       2 print(dados)
#
# NameError: name 'dados' is not defined

# %%
def calculate_score(sentence):
    high_score = 0
    classname = 'default'
    for classe in dados.keys():
        pontos = 0
        pontos = calculate_class_score(sentence,classe)
        if pontos > high_score:
            high_score = pontos
            classname = classe
    return classname,high_score

# %%
def calculate_class_score(sentence,class_name):
    score = 0 
    sentence = Tokenize(sentence)
    sentence = Stemming(sentence)
    for word in sentence:
        if word in dados[class_name]:
            score += dados[class_name][word]
    print(score,class_name)
    return score

# %%
print(calculate_score('Corinthians ganha taça libertadores'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-a301bba50a23> in <module>
# ----> 1 print(calculate_score('Corinthians ganha taça libertadores'))
#
# <ipython-input-11-c2e7318315f3> in calculate_score(sentence)
#       2     high_score = 0
#       3     classname = 'default'
# ----> 4     for classe in dados.keys():
#       5         pontos = 0
#       6         pontos = calculate_class_score(sentence,classe)
#
# NameError: name 'dados' is not defined

# %%
client = MongoClient('mongodb+srv://felipe:a1b2c3d4e5@cluster0-twctd.mongodb.net/news?retryWrites=true')
# Out:
# ---------------------------------------------------------------------------
# Timeout                                   Traceback (most recent call last)
# ~/anaconda3/envs/DataScience/lib/python3.6/site-packages/pymongo/uri_parser.py in _get_dns_srv_hosts(hostname)
#     286     try:
# --> 287         results = resolver.query('_mongodb._tcp.' + hostname, 'SRV')
#     288     except Exception as exc:
#
# ~/anaconda3/envs/DataScience/lib/python3.6/site-packages/dns/resolver.py in query(qname, rdtype, rdclass, tcp, source, raise_on_no_answer, source_port, lifetime)
#    1101                                         raise_on_no_answer, source_port,
# -> 1102                                         lifetime)
#    1103
#
# ~/anaconda3/envs/DataScience/lib/python3.6/site-packages/dns/resolver.py in query(self, qname, rdtype, rdclass, tcp, source, raise_on_no_answer, source_port, lifetime)
#     991                     #
# --> 992                     timeout = self._compute_timeout(start, lifetime)
#     993                     sleep_time = min(timeout, backoff)
#
# ~/anaconda3/envs/DataScience/lib/python3.6/site-packages/dns/resolver.py in _compute_timeout(self, start, lifetime)
#     798         if duration >= lifetime:
# --> 799             raise Timeout(timeout=duration)
#     800         return min(lifetime - duration, self.timeout)
#
# Timeout: The DNS operation timed out after 30.00056505203247 seconds
#
# During handling of the above exception, another exception occurred:
#
# ConfigurationError                        Traceback (most recent call last)
# <ipython-input-240-dcea01e32d45> in <module>
# ----> 1 client = MongoClient('mongodb+srv://felipe:a1b2c3d4e5@cluster0-twctd.mongodb.net/news?retryWrites=true')
#
# ~/anaconda3/envs/DataScience/lib/python3.6/site-packages/pymongo/mongo_client.py in __init__(self, host, port, document_class, tz_aware, connect, **kwargs)
#     492         for entity in host:
#     493             if "://" in entity:
# --> 494                 res = uri_parser.parse_uri(entity, port, warn=True)
#     495                 seeds.update(res["nodelist"])
#     496                 username = res["username"] or username
#
# ~/anaconda3/envs/DataScience/lib/python3.6/site-packages/pymongo/uri_parser.py in parse_uri(uri, default_port, validate, warn)
#     397             raise InvalidURI(
#     398                 "%s URIs must not include a port number" % (SRV_SCHEME,))
# --> 399         nodes = _get_dns_srv_hosts(fqdn)
#     400
#     401         try:
#
# ~/anaconda3/envs/DataScience/lib/python3.6/site-packages/pymongo/uri_parser.py in _get_dns_srv_hosts(hostname)
#     287         results = resolver.query('_mongodb._tcp.' + hostname, 'SRV')
#     288     except Exception as exc:
# --> 289         raise ConfigurationError(str(exc))
#     290     return [(maybe_decode(res.target.to_text(omit_final_dot=True)), res.port)
#     291             for res in results]
#
# ConfigurationError: The DNS operation timed out after 30.00056505203247 seconds

# %%
db = client.news

# %%
#cur = db.rss.find({"section":"mundo", "timestamp":{"$lte":datetime.datetime(2019, 3, 5), "$gte":datetime.datetime(2019, 3, 1)}})
cur = db.rss.find({"section":"sp_mogi_das_cruzes", "timestamp":{"$lte":datetime.now(), "$gte":datetime.now() - timedelta(days=1)}})

# %%
a = []
for doc in cur:
    title = doc['title']
    a.append(title)
str1 = ' '.join(a)

# %%
phrase = []
stopwords = nltk.corpus.stopwords.words('portuguese')
for i in str1.split():
    if i not in stopwords:
        phrase.append(i)
str1 = ' '.join(phrase)

# %%
wordcloud = WordCloud().generate(str1)
plt.figure(figsize=(15, 10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%