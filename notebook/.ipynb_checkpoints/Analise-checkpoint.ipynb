# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import nltk
import datetime
from wordcloud import WordCloud
from nltk.stem import RSLPStemmer
from pymongo import MongoClient

# %%
def Tokenize(sentence):
    sentence = sentence.lower()
    sentence = nltk.word_tokenize(sentence)
    return sentence

# %%
def RemoveStopWords(sentence):
    stopwords = nltk.corpus.stopwords.words('portuguese')
    phrase = []
    for word in sentence:
        if word not in stopwords:
            phrase.append(word)
    return phrase

# %%
def Stemming(sentence):
    stemmer = RSLPStemmer()
    phrase = []
    for word in sentence:
        phrase.append(stemmer.stem(word.lower()))
    return phrase

# %%
frase1 = df.title[0]
frase2 = df.title[2]
print(frase1)
print(frase2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1068c32fd36e> in <module>
# ----> 1 frase1 = df.title[0]
#       2 frase2 = df.title[2]
#       3 print(frase1)
#       4 print(frase2)
#
# NameError: name 'df' is not defined

# %%
nltk.download('rslp')
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package rslp to /Users/Felipe/nltk_data...
# [nltk_data]   Package rslp is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/Felipe/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/Felipe/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def Train():
    training_data = []
    for row in df.iterrows():
        training_data.append({"classe":row[1][1], "frase":row[1][3]})
    print("%s frases incluidas" % len(training_data))
    return training_data

# %%
dados = Train()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-7b1e110c8841> in <module>
# ----> 1 dados = Train()
#
# <ipython-input-7-b0dacb027d2c> in Train()
#       1 def Train():
#       2     training_data = []
# ----> 3     for row in df.iterrows():
#       4         training_data.append({"classe":row[1][1], "frase":row[1][3]})
#       5     print("%s frases incluidas" % len(training_data))
#
# NameError: name 'df' is not defined

# %%
def Learning(training_data):
    corpus_words = {}
    for data in training_data:
        frase = data['frase']
        frase = Tokenize(frase)
        frase = Stemming(frase)
        frase = RemoveStopWords(frase)
        class_name = data['classe']
        if class_name not in list(corpus_words.keys()):
            corpus_words[class_name] = {}
        for word in frase:
            if word not in list(corpus_words[class_name].keys()):
                corpus_words[class_name][word] = 1
            else:
                corpus_words[class_name][word] += 1
    return corpus_words

# %%
dados = Learning(dados)
print(dados)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4c711032b263> in <module>
# ----> 1 dados = Learning(dados)
#       2 print(dados)
#
# NameError: name 'dados' is not defined

# %%
def calculate_score(sentence):
    high_score = 0
    classname = 'default'
    for classe in dados.keys():
        pontos = 0
        pontos = calculate_class_score(sentence,classe)
        if pontos > high_score:
            high_score = pontos
            classname = classe
    return classname,high_score

# %%
def calculate_class_score(sentence,class_name):
    score = 0 
    sentence = Tokenize(sentence)
    sentence = Stemming(sentence)
    for word in sentence:
        if word in dados[class_name]:
            score += dados[class_name][word]
    print(score,class_name)
    return score

# %%
print(calculate_score('Corinthians ganha taça libertadores'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-a301bba50a23> in <module>
# ----> 1 print(calculate_score('Corinthians ganha taça libertadores'))
#
# <ipython-input-11-c2e7318315f3> in calculate_score(sentence)
#       2     high_score = 0
#       3     classname = 'default'
# ----> 4     for classe in dados.keys():
#       5         pontos = 0
#       6         pontos = calculate_class_score(sentence,classe)
#
# NameError: name 'dados' is not defined

# %%
client = MongoClient('mongodb+srv://felipe:a1b2c3d4e5@cluster0-twctd.mongodb.net/news?retryWrites=true')

# %%
db = client.news

# %%
#cur = db.rss.find({"section":"mundo", "timestamp":{"$lte":datetime.datetime(2019, 3, 5), "$gte":datetime.datetime(2019, 3, 1)}})
cur = db.rss.find({"section":"politica", "timestamp":{"$lte":datetime.datetime(2019, 3, 12), "$gte":datetime.datetime(2019, 3, 11)}})

# %%
a = []
for doc in cur:
    title = doc['title']
    a.append(title)
str1 = ''.join(a)

# %%
phrase = []
stopwords = nltk.corpus.stopwords.words('portuguese')
for i in str1.split():
    if i not in stopwords:
        phrase.append(i)
str1 = ' '.join(phrase)

# %%
wordcloud = WordCloud().generate(str1)
plt.figure(figsize=(15, 10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
str1
# Out:
# "Bolsonaro pede saída ‘número 2’ MEC após briga 'olavistas'Estados ajuda durante reformasO triste cenário mulheres políticaPrevidência Câmara, Brexit IPCA: tudo precisa acompanhar nesta semana mercadoBolsonaro envolve nova polêmica usar declaração distorcida atacar jornalistaProjeto previdência militares aumento salarial, diz MarinhoNovo presidente BC fará primeiro discurso oficial quarta-feiraBolsonaro agenda internacional intensa partir deste mêsFalas antigas Bolsonaro viram arma servidores contra reforma PrevidênciaServidores preparam lobby pesado barrar reforma PrevidênciaCiro: Não chance Previdência desvinculação passarem juntasCongresso impõe primeiros desafios governo Bolsonaro aprovar reforma PrevidênciaMinistro Educação pode ser próximo cair Olavo Carvalho sugere substitutos, diz EstadãoGoverno exonera seis integrantes alto escalão Ministério EducaçãoGoverno nega coronel cuidará redes sociais PlanaltoLíder governo anuncia liberação R$ 1 bi emendas parlamentares"
